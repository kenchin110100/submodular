# %%
# coding: utf-8
"""
SubModularを実験するためのコード
"""
from filer2.filer2 import Filer
from library.submodular import SubModular, Rouge_N
import numpy as np
import glob

# %%
list_test_path = glob.glob('./files/OpinosisDataset1.0/preprocessed/test/*')
list_ans_path = glob.glob('./files/OpinosisDataset1.0/preprocessed/ans/*')

list_test_path.sort()
list_ans_path.sort()

# %%
for test_path, ans_path in zip(list_test_path, list_ans_path):
    dict_test = Filer.readdump(test_path)
    dict_ans = Filer.readdump(ans_path)
    filename = ans_path.replace('./files/OpinosisDataset1.0/preprocessed/ans/', '')
    filename = filename.replace('.dump', '')
    # テスト用ファイルの作成
    # １００単語以上ある文は除く
    list_sentence = []
    list_sep = []
    list_sep_all = []
    list_edgelist = []
    for sen, sep, sepall, edge in zip(dict_test['sentence'],
                                      dict_test['sep_all'],
                                      dict_test['sep_all'],
                                      dict_test['edge_all']):
        if len(sepall) <= 100 and len(sep) != 0:
            list_sentence.append(sen)
            list_sep.append(sep)
            list_sep_all.append(sepall)
            list_edgelist.append(edge)

    list_edgelist = [[row1[0], row1[1]] for row in list_edgelist for row1 in row]
    
    # インスタンス化
    SM = SubModular(list_sep_all=list_sep_all,
                    list_sep=list_sep)
    for alpha in [0.01, 0.05, 0.1, 0.2]:
        for lamda in [0.5, 1, 5, 10]:
            for r in [0.1, 0.5, 1, 2]:
                # 学習
                n_cluster = len(list_sep_all)/5
                SM.m_greedy(num_w=100, alpha=alpha, lamda=lamda, r=r, n_cluster=n_cluster)
                # Rougeを計算するようにbag_of_wordsを作成する
                list_sm_test = [row[2] for row in SM.list_C]
                for row in dict_ans['sep_all']:
                    try:
                        R1 = Rouge_N.rouge(list_sm_test, row, N=1)
                    except:
                        R1 = 0
                    try:
                        R2 = Rouge_N.rouge(list_sm_test, row, N=2)
                    except:
                        R2 = 0
                    try:
                        R3 = Rouge_N.rouge(list_sm_test, row, N=3)
                    except:
                        R3 = 0
                    try:
                        R4 = Rouge_N.rouge(list_sm_test, row, N=4)
                    except:
                        R4 = 0
                    list_result = [[filename, alpha, lamda, r, R1, R2, R3, R4]]
                    Filer.writecsv(list_result, './files/OpinosisDataset1.0/result/SM/all/all_%s_%s_%s.csv'%(alpha, lamda, r))
# Out:
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  67
# num word:  1191
# num vocabulary:  364
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  88
# num word:  1460
# num vocabulary:  399
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  89
# num word:  1795
# num vocabulary:  476
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  69
# num word:  1175
# num vocabulary:  339
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  333
# num word:  6371
# num vocabulary:  1132
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  164
# num word:  3294
# num vocabulary:  686
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  166
# num word:  2585
# num vocabulary:  617
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  119
# num word:  1811
# num vocabulary:  496
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  99
# num word:  2126
# num vocabulary:  579
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# num vocabulary:  347
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# num vocabulary:  347
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# num vocabulary:  347
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# num vocabulary:  347
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# num vocabulary:  347
# 計算が終了しました
# property: list_C
# num_sentence:  50
# num word:  1052
# ...
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  167
# num word:  3059
# num vocabulary:  764
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  194
# num word:  3623
# num vocabulary:  857
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  86
# num word:  1858
# num vocabulary:  539
# 計算が終了しました
# property: list_C
# num_sentence:  101
# num word:  1533
# num vocabulary:  409
# 計算が終了しました
# property: list_C
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-a706104b0641> in <module>()
#      36                     R2 = Rouge_N.rouge(list_sm_test, row, N=2)
#      37                     R3 = Rouge_N.rouge(list_sm_test, row, N=3)
# ---> 38                     R4 = Rouge_N.rouge(list_sm_test, row, N=4)
#      39                     list_result = [[filename, alpha, lamda, r, R1, R2, R3, R4]]
#      40                     Filer.writecsv(list_result, './files/OpinosisDataset1.0/result/SM/all/all_%s_%s_%s.csv'%(alpha, lamda, r))
#
# /home/ikegami/documents/submodular/library/submodular.py in rouge(cls, list_sep_test, list_sep_ans, N)
#     894                 numer += np.amin([dict_ans_count[key], value])
#     895
# --> 896         return float(numer)/denom
#
# ZeroDivisionError: float division by zero
